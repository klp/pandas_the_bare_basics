# %%
import pandas as pd

# %%
df = pd.read_csv('http://bit.ly/airbnbcsv')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# See first 10 rows
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.head(15) # See the first 15
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
df.tail(15)  # last 15 rows
# Out:
#              id                                               name    host_id  \
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48881  36481615                   Peaceful space in Greenpoint, BK  274298453
# 48882  36482231                          Bushwick _ Myrtle-Wyckoff   66058896
# 48883  36482416       Sunny Bedroom NYC! Walking to Central Park!!  131529729
# 48884  36482783        Brooklyn Oasis in the heart of Williamsburg  274307600
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# ...

# %%
# Get basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.neighbourhood_group # see what's in there
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
#            ...
# 48890     Brooklyn
# 48891     Brooklyn
# 48892    Manhattan
# 48893    Manhattan
# 48894    Manhattan
# Name: neighbourhood_group, Length: 48895, dtype: object

# %%
df.neighbourhood_group.unique() # see unique
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df.columns # see columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.price # produces a series
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
df.price.mean()
# Out:
# 152.7206871868289

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# average higher than median suggestions most airbnb are around 100
# but that there might be a few very expensive ones

# %%
df.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
len(df.neighbourhood.unique())
# Out:
# 221

# %%
# create subset 
woodside_bools = df.neighbourhood == 'Woodside' # boolean list
woodside_bools
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Name: neighbourhood, Length: 48895, dtype: bool

# %%
# Use variable above

woodside_df = df[woodside_bools] # gives you only Woodside records 
woodside_df
# Out:
#              id                                               name    host_id  \
# 77        18198                              Little King of Queens      70091
# 746      270231                   Cozy New York  City private room    1366310
# 1218     519310                                    YOU ROOM IN NYC    1366310
# 1556     704838                       An Oasis in  the Big Apple 1    3621183
# 1573     714028                        An Oasis in the Big Apple 2    3621183
# ...         ...                                                ...        ...
# 47203  35634704  WOODSIDE COMFORTABLE ROOM 15 MINUTES FROM THE ...  266792224
# 47404  35716084               Private rooms And Matchless Location  233050530
# 47712  35876561  Modern house (2 BR Apt) • 30Mins from Time Squ...   76360760
# 48056  36062221                                    SHORT TERM STAY    9037589
# 48431  36265137  Cozy, modern room close to Manhattan for 2 guests  272748063
#
# ...

# %%
woodside_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 77 to 48431
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              235 non-null    int64
#  1   name                            235 non-null    object
#  2   host_id                         235 non-null    int64
#  3   host_name                       235 non-null    object
#  4   neighbourhood_group             235 non-null    object
#  5   neighbourhood                   235 non-null    object
#  6   latitude                        235 non-null    float64
#  7   longitude                       235 non-null    float64
#  8   room_type                       235 non-null    object
#  9   price                           235 non-null    int64
#  10  minimum_nights                  235 non-null    int64
#  11  number_of_reviews               235 non-null    int64
# ...

# %%
woodside_df.price.describe()
# Out:
# count    235.000000
# mean      85.097872
# std       70.724116
# min       28.000000
# 25%       44.500000
# 50%       60.000000
# 75%      100.000000
# max      500.000000
# Name: price, dtype: float64

# %%
# Create little data frames jammed together, then run average and collapses group by
df.groupby(['neighbourhood_group']) # creates five little dataframes by neighbourhood group

# %%
# Need to collapse it again to get something useful
df.groupby(['neighbourhood_group']).price.mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
# Sort in order
df.groupby(['neighbourhood_group']).price.mean().sort_values()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Queens            99.517649
# Staten Island    114.812332
# Brooklyn         124.383207
# Manhattan        196.875814
# Name: price, dtype: float64

# %%
# Save series to variable
gentrification = df.groupby(['neighbourhood_group']).price.mean().sort_values()

# %%
# make a chart
gentrification.plot(kind='bar')
# Out:
# Unable to revert mtime: /Library/Fonts
# <AxesSubplot:xlabel='neighbourhood_group'>

# %%
group_and_hood = df.groupby(['neighbourhood_group','neighbourhood']).price.mean().sort_values()
group_and_hood
# Out:
# neighbourhood_group  neighbourhood
# Staten Island        Bull's Head        47.333333
# Bronx                Hunts Point        50.500000
#                      Tremont            51.545455
#                      Soundview          53.466667
# Staten Island        New Dorp           57.000000
#                                           ...
# Bronx                Riverdale         442.090909
# Brooklyn             Sea Gate          487.857143
# Manhattan            Tribeca           490.638418
# Staten Island        Woodrow           700.000000
#                      Fort Wadsworth    800.000000
# Name: price, Length: 221, dtype: float64

# %%
hood = df.groupby(['neighbourhood']).price.mean().sort_values()

hood = hood.head(10) # 10 cheapest neighborhoods

hood
# Out:
# neighbourhood
# Bull's Head       47.333333
# Hunts Point       50.500000
# Tremont           51.545455
# Soundview         53.466667
# New Dorp          57.000000
# Bronxdale         57.105263
# New Dorp Beach    57.400000
# Grant City        57.666667
# Concord           58.192308
# Mount Eden        58.500000
# Name: price, dtype: float64

# %%
hood.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='neighbourhood'>

# %%
hood = df.groupby(['neighbourhood']).price.mean().sort_values()

hood = hood.tail(10) # 10 cheapest neighborhoods

hood
# Out:
# neighbourhood
# NoHo                 295.717949
# Randall Manor        336.000000
# Flatiron District    341.925000
# Battery Park City    367.557143
# Prince's Bay         409.500000
# Riverdale            442.090909
# Sea Gate             487.857143
# Tribeca              490.638418
# Woodrow              700.000000
# Fort Wadsworth       800.000000
# Name: price, dtype: float64

# %%
hood.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='neighbourhood'>

# %%
# Working with textual information
df.name.sample(n=10) # rows/indexes
# Out:
# 16269    West 33rd street, Lux Studio Serviced Apartment
# 44597                                  Yellow  ButterFly
# 22112    Bunk Bed Fun Room - really cozy and affordable!
# 46272                                          Blue Room
# 12290                        Modern 1 Bedroom Harlem Apt
# 1685                     Beautiful 3 bedroom apartment!!
# 15236                 Spacious, sunny room in Greenpoint
# 36774     2 bedroom CONDO off 5th Ave - BRIGHT and homey
# 45569         Renovated Sutton Place Apartment- Free Gym
# 42426     HUGE & Sunny Two Bedroom Apartment in Brooklyn
# Name: name, dtype: object

# %%
# find data set with cozy in name
# first make text lowercase
cozy_bools = df.name.str.lower().str.contains('cozy') == True # turns all empty/Nan/null name values into false

cozy_df = df[cozy_bools]

cozy_df
# Out:
#              id                                             name    host_id  \
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 5          5099        Large Cozy 1 BR Apartment In Midtown East       7322
# 8          5203               Cozy Clean Guest Room - Family Apt       7490
# 9          5238               Cute & Cozy Lower East Side 1 bdrm       7549
# 51        14287   Cozy 1BD on Central Park West in New York City      56094
# ...         ...                                              ...        ...
# 48866  36472710                               CozyHideAway Suite  274225617
# 48869  36474023                      Cozy, Sunny Brooklyn Escape    1550580
# 48870  36474911    Cozy, clean Williamsburg 1- bedroom apartment    1273444
# 48876  36478357  Cozy, Air-Conditioned Private Bedroom in Harlem  177932088
# 48893  36485609             43rd St. Time Square-cozy single bed   30985759
#
# ...

# %%
cozy_df.price.describe()
# Out:
# count    5111.000000
# mean      104.755038
# std        92.045383
# min         0.000000
# 25%        58.000000
# 50%        85.000000
# 75%       129.000000
# max      2500.000000
# Name: price, dtype: float64

# %%
# What neighbourhood's are the most cozy could be a cool next step
